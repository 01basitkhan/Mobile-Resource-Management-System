# %%
import pandas as pd

data = pd.read_csv('data.csv')

# %%
import matplotlib.pyplot as plt
labels = [
    'Crane', 'Forklift', 'Boom Lift', 'Scissor Lift', 
    'Excavator', 'Bulldozer', 'Tow Truck', 'Mobile Generator', 
    'Concrete Pump', 'Mobile Medical Unit'
]
utilization = [85, 75, 95, 80, 70, 100, 90, 85, 60, 90]
fig, ax = plt.subplots()
ax.pie(utilization, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal') 
plt.title(' Available Mobile Resources')
plt.show()
